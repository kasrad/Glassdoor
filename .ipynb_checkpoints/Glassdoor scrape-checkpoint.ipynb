# %% [markdown]
# # Glassdoor scrape

# %% [markdown]
# via this script I aim to scrape reported salaries from glassdoor for a specific role in a specific city

# %% [markdown]
# #### test - Android Developer Boston

# %%
from jupyterthemes import jtplot
import urllib
import json
import numpy as np
import matplotlib.pyplot as plt

url = 'https://www.glassdoor.com/Job/jobs.htm?suggestCount=0&suggest\
Chosen=false&clickSource=searchBtn&typedKeyword=\
Android+Developer&sc.keyword=Android+Developer&locT=C&locId=1154532&jobType='
headers = { 'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36' }
data=bytes(json.dumps(headers), encoding="utf-8")
req = urllib.request.Request(url, data, headers)
with urllib.request.urlopen(req) as response:
    the_page = response.read()
print(urllib.request.urlopen(req))

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(the_page, 'html.parser')
soup.find_all("i", class_="info infoSalEst margLtSm")
tag = soup.find_all(attrs={"data-displayed-max-salary": True})

min_sal = np.zeros(0)
for obj in soup.find_all('i', class_="info infoSalEst margLtSm"):
    print(obj.get("data-displayed-min-salary"))
    min_sal = np.append(min_sal,float(obj.get("data-displayed-min-salary")))

print(min_sal)

# %%
plt.hist(min_sal)
plt.show()

# %% [markdown]
# unfortunately, glassdoor.com does not report estimated salaries for all roles, therefore we need to scrape the 'Salaries' section of Glassdoor

# %% [markdown]
# #### Data Scientist London

# %%
import urllib
import json
import numpy as np
import matplotlib.pyplot as plt
import jupyterthemes.jtplot as jtplot
from bs4 import BeautifulSoup

#specify URL - should be automated
url = 'https://www.glassdoor.co.uk/Salaries/london-data-scientist-salary-SRCH_IL.\
0,6_IM1035_KO7,21.htm'

#standard python user agent is blocked
headers = { 'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36' }
data=bytes(json.dumps(headers), encoding="utf-8")
req = urllib.request.Request(url, data, headers)
with urllib.request.urlopen(req) as response:
    the_page = response.read()
print(urllib.request.urlopen(req))

# %%
the_page

# %%
#use beatiful soup for parsing
soup = BeautifulSoup(the_page, 'html.parser')

#obtain min and max salaries
min_sal = np.zeros(0)
max_sal = np.zeros(0)
for obj in soup.find_all("div", class_="JobInfoStyle__range formFactorHelpers__showHH"):
    min_sal = np.append(min_sal, obj.text[8:10])
    max_sal = np.append(max_sal, obj.text[15:17])

# for maxobj in soup.find_all("div", class_="minor cell alignRt maxPay"):
#      max_sal = np.append(max_sal, maxobj.text[15:17])

# #convert into numbers
# min_sal = np.char.replace(min_sal, 'k', '000')
# min_sal = np.char.replace(min_sal, '£', '')
# max_sal = np.char.replace(max_sal, 'k', '000')
# max_sal = np.char.replace(max_sal, '£', '')

min_sal = min_sal.astype(int)
max_sal = max_sal.astype(int)
     
salaries = np.zeros((min_sal.shape[0], 3))
salaries[:,0] = min_sal
salaries[:,1] = max_sal
salaries = salaries[salaries[:, 0].argsort()]
salaries[:,2] = range(max_sal.shape[0])

# %%
import re
import pandas as pd

result_set = soup.find_all("div", class_="JobInfoStyle__employerName")

output = np.zeros((len(result_set),1)) 
output = pd.DataFrame(output)
print(output.shape)
j = 0
for i in result_set:
                  output.iloc[j,0] = i.text
                  j +=1

# %%
print(min_sal.shape)
print(max_sal.shape)
print(output.shape)
pd.DataFrame(min_sal)

# %%
salaries = pd.concat([pd.DataFrame(min_sal), pd.DataFrame(max_sal), output], axis = 1)
salaries.columns = ['min', 'max', 'employer']
print(salaries)
salaries = salaries.sort_values(by = 'min')
salaries = salaries.iloc[1:, :]
print(salaries)
# Out:
#     min  max                          employer
# 0    24   60                         Capgemini
# 1    40   88                         Dunnhumby
# 2    52   95                          Elsevier
# 3    43   60                  Imagini Holdings
# 4    43   47                             Tesco
# 5    40   52                          Barclays
# 6    29   46                       J Sainsbury
# 7    35   40                          Unilever
# 8    39   57                      Virgin Media
# 9    36   41                             Ocado
# 10   38   58                              Zopa
# 11   34   36  Department for Work And Pensions
# 12   48   52                         Accenture
# 13   48   52                               IBM
# 14   19    1                     HSBC Holdings
# 15   34   36                            Capita
# 16   33   36                               NHS
# 17   64   70                               Sky
# 18   57   62                     Deutsche Bank
# 19   67   73                            Amazon
#     min  max                          employer
# 0    24   60                         Capgemini
# 6    29   46                       J Sainsbury
# 16   33   36                               NHS
# 15   34   36                            Capita
# 11   34   36  Department for Work And Pensions
# 7    35   40                          Unilever
# 9    36   41                             Ocado
# 10   38   58                              Zopa
# 8    39   57                      Virgin Media
# 1    40   88                         Dunnhumby
# 5    40   52                          Barclays
# 4    43   47                             Tesco
# 3    43   60                  Imagini Holdings
# 12   48   52                         Accenture
# 13   48   52                               IBM
# 2    52   95                          Elsevier
# 18   57   62                     Deutsche Bank
# 17   64   70                               Sky
# 19   67   73                            Amazon

# %%
salaries['order'] = np.arange(1,20,1)

# %%
#plot
jtplot.style('monokai')
# plt.plot(salaries['min'])
# plt.plot(salaries['max'])
# plt.legend(['min', 'max'], ncol=1, loc='upper left', 
#            columnspacing=1.0, labelspacing=0.0,
#            handletextpad=0.5, handlelength=1.5,
#            fancybox=True, shadow=True)
# plt.title('Data Scientist salaries - London')
# plt.show()
# plt.clf()
#bckgr colour is #2f2f2f
plt.bar(x = salaries['order'], height = salaries['max'], width = 1, color = 'orange', alpha = 0.7)
plt.bar(x = salaries['order'], height = salaries['min'], width = 1, color = '#232323')
plt.legend(['range'], ncol=1, loc='upper left', 
           columnspacing=1.0, labelspacing=0.0,
           handletextpad=0.5, handlelength=1.5,
           fancybox=True, shadow=True)
plt.title('Data Scientist salaries - London')
plt.xticks(salaries['order'], salaries['employer'], rotation = 60, ha='right')
plt.tight_layout()
plt.savefig('DataScientistSalaries.png', dpi = 1000)
plt.show()
salaries
# Out:
#     min  max                          employer  order
# 0    24   60                         Capgemini      1
# 6    29   46                       J Sainsbury      2
# 16   33   36                               NHS      3
# 15   34   36                            Capita      4
# 11   34   36  Department for Work And Pensions      5
# 7    35   40                          Unilever      6
# 9    36   41                             Ocado      7
# 10   38   58                              Zopa      8
# 8    39   57                      Virgin Media      9
# 1    40   88                         Dunnhumby     10
# 5    40   52                          Barclays     11
# 4    43   47                             Tesco     12
# 3    43   60                  Imagini Holdings     13
# 12   48   52                         Accenture     14
# 13   48   52                               IBM     15
# 2    52   95                          Elsevier     16
# 18   57   62                     Deutsche Bank     17
# 17   64   70                               Sky     18
# 19   67   73                            Amazon     19
